# %%
import numpy as np
import librosa
import librosa.display
import os
import shutil

# %%
# load audio folder. Put whatever files you want to organize in here. 
directory = 'audio_files'
file = ''
sum=0
OUTPUT_BY_AVG = "output_by_avg"
OUTPUT_BY_LENGTH = "output_by_length"
OUTPUT_BY_SUM = "output_by_sum"
OUTPUT_BY_MAX_RMS = "output_by_max_rms"


for filename in os.listdir(directory) :
    if not filename.startswith('.'):
        f = os.path.join(directory, filename)

        print(f)
        if os.path.isfile(f):
            file = f
            current_file, _ = librosa.load(file)
            rms_current_file = librosa.feature.rms(y=current_file)[0]
            # print("the directory is:  " + file)
            print("FILE:  " + filename)
            print(file)
            
            arr = rms_current_file
            array_length=len(arr)
            max_rms = arr.max()*1000
            for i in range(0, len(arr)):
                sum=sum+arr[i]
            
            # sets variable with avg RMS value + filename
            new_name_avg =  str(sum/array_length*100) + " " + str(filename)
            
            # sets variable with max rms + filename
            new_name_max_rms =  str(max_rms) + " " + str(filename)
            
            # sets variable sum value + filename
            new_name_sum =  str(sum) + " " + str(filename)

            # sets variable length value + filename
            new_name_length =  str(array_length) + " " + str(filename)
            

            print("New Filename: " + new_name_avg)
            print("Sum of all the elements of the array: " + str(sum));    
            print("The length of the array is: " + str(array_length));    
            print("The average RMS of the sample is " + str(sum/array_length*100));
            print("The max RMS value is: " + str(max_rms))
            print("")
        
            
            # copies to max_rms output folder
            shutil.copy(file, OUTPUT_BY_MAX_RMS)
            old_name = OUTPUT_BY_MAX_RMS+"/"+filename
            rename = OUTPUT_BY_MAX_RMS+"/"+new_name_max_rms
            os.rename(old_name, rename)
            
            # # copies the source files to output_by_avg
            # shutil.copy(file, OUTPUT_BY_AVG)

            # # renames the copied files with avg RMS as prefix
            # old_name = OUTPUT_BY_AVG+"/"+filename
            # rename = OUTPUT_BY_AVG+"/"+new_name_avg
            # os.rename(old_name, rename)
        

            # # copies the source files to output_by_sum
            # shutil.copy(file, OUTPUT_BY_SUM)
            
            # # # renames the copied files with sum as prefix
            # old_name = OUTPUT_BY_SUM+"/"+filename
            # rename = OUTPUT_BY_SUM+"/"+new_name_sum
            # os.rename(old_name, rename)
            
        
            #  # copies the source files to output_by_length
            # shutil.copy(file, OUTPUT_BY_LENGTH)

            # # renames the copied files with sum as prefix
            # old_name = OUTPUT_BY_LENGTH+"/"+filename
            # rename = OUTPUT_BY_LENGTH+"/"+new_name_length
            # os.rename(old_name, rename)
# Out:
# audio_files/8039 - home depot samples 96k-0060.wav
# FILE:  8039 - home depot samples 96k-0060.wav
# audio_files/8039 - home depot samples 96k-0060.wav
# New Filename: 0.1287189879839197 8039 - home depot samples 96k-0060.wav
# Sum of all the elements of the array: 0.09396486122826139
# The length of the array is: 73
# The average RMS of the sample is 0.1287189879839197
# The max RMS value is: 10.181195102632046
#
# audio_files/8039 - home depot samples 96k-6411.wav
# FILE:  8039 - home depot samples 96k-6411.wav
# audio_files/8039 - home depot samples 96k-6411.wav
# New Filename: 0.36224392588268 8039 - home depot samples 96k-6411.wav
# Sum of all the elements of the array: 0.1956117199766472
# The length of the array is: 54
# The average RMS of the sample is 0.36224392588268
# The max RMS value is: 13.118305243551731
#
# audio_files/8039 - home depot samples 96k-2677.wav
# FILE:  8039 - home depot samples 96k-2677.wav
# audio_files/8039 - home depot samples 96k-2677.wav
# New Filename: 0.554161731748028 8039 - home depot samples 96k-2677.wav
# Sum of all the elements of the array: 0.33803865636629704
# The length of the array is: 61
# The average RMS of the sample is 0.554161731748028
# The max RMS value is: 13.547918759286404
#
# audio_files/8039 - home depot samples 96k-5118.wav
# FILE:  8039 - home depot samples 96k-5118.wav
# audio_files/8039 - home depot samples 96k-5118.wav
# New Filename: 1.2501197471942018 8039 - home depot samples 96k-5118.wav
# Sum of all the elements of the array: 0.7625730457884632
# The length of the array is: 61
# The average RMS of the sample is 1.2501197471942018
# The max RMS value is: 38.94106671214104
#
# audio_files/8039 - home depot samples 96k-4206.wav
# FILE:  8039 - home depot samples 96k-4206.wav
# audio_files/8039 - home depot samples 96k-4206.wav
# New Filename: 1.6993161042932938 8039 - home depot samples 96k-4206.wav
# Sum of all the elements of the array: 0.9686101794471774
# The length of the array is: 57
# The average RMS of the sample is 1.6993161042932938
# The max RMS value is: 25.16956813633442
#
# audio_files/8039 - home depot samples 96k-3569.wav
# FILE:  8039 - home depot samples 96k-3569.wav
# audio_files/8039 - home depot samples 96k-3569.wav
# New Filename: 2.037600471820568 8039 - home depot samples 96k-3569.wav
# Sum of all the elements of the array: 1.0391762406284897
# The length of the array is: 51
# The average RMS of the sample is 2.037600471820568
# The max RMS value is: 9.633518755435944
#
# audio_files/8039 - home depot samples 96k-4560.wav
# FILE:  8039 - home depot samples 96k-4560.wav
# audio_files/8039 - home depot samples 96k-4560.wav
# New Filename: 2.131056311778232 8039 - home depot samples 96k-4560.wav
# Sum of all the elements of the array: 1.1507704083602455
# The length of the array is: 54
# The average RMS of the sample is 2.131056311778232
# The max RMS value is: 10.991423390805721
#
# audio_files/8039 - home depot samples 96k-2111.wav
# FILE:  8039 - home depot samples 96k-2111.wav
# audio_files/8039 - home depot samples 96k-2111.wav
# New Filename: 2.2587531866034554 8039 - home depot samples 96k-2111.wav
# Sum of all the elements of the array: 1.2423142526319004
# The length of the array is: 55
# The average RMS of the sample is 2.2587531866034554
# The max RMS value is: 16.31322130560875
#
# audio_files/8039 - home depot samples 96k-1418.wav
# FILE:  8039 - home depot samples 96k-1418.wav
# audio_files/8039 - home depot samples 96k-1418.wav
# New Filename: 2.7317482474643953 8039 - home depot samples 96k-1418.wav
# Sum of all the elements of the array: 1.3658741237321976
# The length of the array is: 50
# The average RMS of the sample is 2.7317482474643953
# The max RMS value is: 21.593894809484482
#
# audio_files/8039 - home depot samples 96k-6377.wav
# FILE:  8039 - home depot samples 96k-6377.wav
# audio_files/8039 - home depot samples 96k-6377.wav
# New Filename: 2.3315784667475024 8039 - home depot samples 96k-6377.wav
# Sum of all the elements of the array: 1.4922102187184014
# The length of the array is: 64
# The average RMS of the sample is 2.3315784667475024
# The max RMS value is: 7.779367733746767
#
# audio_files/8039 - home depot samples 96k-7069.wav
# FILE:  8039 - home depot samples 96k-7069.wav
# audio_files/8039 - home depot samples 96k-7069.wav
# New Filename: 3.159351619479786 8039 - home depot samples 96k-7069.wav
# Sum of all the elements of the array: 1.5796758097398929
# The length of the array is: 50
# The average RMS of the sample is 3.159351619479786
# The max RMS value is: 12.86151260137558
#
# audio_files/8039 - home depot samples 96k-0706.wav
# FILE:  8039 - home depot samples 96k-0706.wav
# audio_files/8039 - home depot samples 96k-0706.wav
# New Filename: 3.234134262446676 8039 - home depot samples 96k-0706.wav
# Sum of all the elements of the array: 1.6170671312233378
# The length of the array is: 50
# The average RMS of the sample is 3.234134262446676
# The max RMS value is: 7.314172573387623
#
# audio_files/8039 - home depot samples 96k-6363.wav
# FILE:  8039 - home depot samples 96k-6363.wav
# audio_files/8039 - home depot samples 96k-6363.wav
# New Filename: 3.305847968719311 8039 - home depot samples 96k-6363.wav
# Sum of all the elements of the array: 1.7190409437340417
# The length of the array is: 52
# The average RMS of the sample is 3.305847968719311
# The max RMS value is: 12.165185064077377
#
# audio_files/8039 - home depot samples 96k-0712.wav
# FILE:  8039 - home depot samples 96k-0712.wav
# audio_files/8039 - home depot samples 96k-0712.wav
# New Filename: 3.35272636524748 8039 - home depot samples 96k-0712.wav
# Sum of all the elements of the array: 1.7769449735811644
# The length of the array is: 53
# The average RMS of the sample is 3.35272636524748
# The max RMS value is: 7.433308754116297
#
# audio_files/8039 - home depot samples 96k-4574.wav
# FILE:  8039 - home depot samples 96k-4574.wav
# audio_files/8039 - home depot samples 96k-4574.wav
# New Filename: 2.996232823041096 8039 - home depot samples 96k-4574.wav
# Sum of all the elements of the array: 1.9175890067463015
# The length of the array is: 64
# The average RMS of the sample is 2.996232823041096
# The max RMS value is: 9.122502990067005
#
# audio_files/8039 - home depot samples 96k-2105.wav
# FILE:  8039 - home depot samples 96k-2105.wav
# audio_files/8039 - home depot samples 96k-2105.wav
# New Filename: 3.212488871396658 8039 - home depot samples 96k-2105.wav
# Sum of all the elements of the array: 2.0881177664078274
# The length of the array is: 65
# The average RMS of the sample is 3.212488871396658
# The max RMS value is: 28.35937775671482
#
# audio_files/8039 - home depot samples 96k-2663.wav
# FILE:  8039 - home depot samples 96k-2663.wav
# audio_files/8039 - home depot samples 96k-2663.wav
# New Filename: 3.8738749006289894 8039 - home depot samples 96k-2663.wav
# Sum of all the elements of the array: 2.1693699443522343
# The length of the array is: 56
# The average RMS of the sample is 3.8738749006289894
# The max RMS value is: 7.287126500159502
#
# audio_files/8039 - home depot samples 96k-4212.wav
# FILE:  8039 - home depot samples 96k-4212.wav
# audio_files/8039 - home depot samples 96k-4212.wav
# New Filename: 4.305341976209605 8039 - home depot samples 96k-4212.wav
# Sum of all the elements of the array: 2.2387778276289945
# The length of the array is: 52
# The average RMS of the sample is 4.305341976209605
# The max RMS value is: 8.326034992933273
#
# audio_files/8039 - home depot samples 96k-0074.wav
# FILE:  8039 - home depot samples 96k-0074.wav
# audio_files/8039 - home depot samples 96k-0074.wav
# New Filename: 4.537005271330404 8039 - home depot samples 96k-0074.wav
# Sum of all the elements of the array: 2.268502635665202
# The length of the array is: 50
# The average RMS of the sample is 4.537005271330404
# The max RMS value is: 7.82239343971014
#
# audio_files/8039 - home depot samples 96k-6405.wav
# FILE:  8039 - home depot samples 96k-6405.wav
# audio_files/8039 - home depot samples 96k-6405.wav
# New Filename: 4.4633715268856395 8039 - home depot samples 96k-6405.wav
# Sum of all the elements of the array: 2.365586909249389
# The length of the array is: 53
# The average RMS of the sample is 4.4633715268856395
# The max RMS value is: 11.53641939163208
#
# audio_files/8039 - home depot samples 96k-5124.wav
# FILE:  8039 - home depot samples 96k-5124.wav
# audio_files/8039 - home depot samples 96k-5124.wav
# New Filename: 4.444973734991797 8039 - home depot samples 96k-5124.wav
# Sum of all the elements of the array: 2.6669842409950784
# The length of the array is: 60
# The average RMS of the sample is 4.444973734991797
# The max RMS value is: 38.34926709532738
#
# audio_files/8039 - home depot samples 96k-2893.wav
# FILE:  8039 - home depot samples 96k-2893.wav
# audio_files/8039 - home depot samples 96k-2893.wav
# New Filename: 4.260180683448737 8039 - home depot samples 96k-2893.wav
# Sum of all the elements of the array: 2.896922864745141
# The length of the array is: 68
# The average RMS of the sample is 4.260180683448737
# The max RMS value is: 20.14697901904583
#
# audio_files/8039 - home depot samples 96k-3555.wav
# FILE:  8039 - home depot samples 96k-3555.wav
# audio_files/8039 - home depot samples 96k-3555.wav
# New Filename: 5.0358035633311715 8039 - home depot samples 96k-3555.wav
# Sum of all the elements of the array: 3.0214821379987025
# The length of the array is: 60
# The average RMS of the sample is 5.0358035633311715
# The max RMS value is: 8.050790056586266
#
# audio_files/8039 - home depot samples 96k-7733.wav
# FILE:  8039 - home depot samples 96k-7733.wav
# audio_files/8039 - home depot samples 96k-7733.wav
# New Filename: 5.783838672193861 8039 - home depot samples 96k-7733.wav
# Sum of all the elements of the array: 3.123272882984685
# The length of the array is: 54
# The average RMS of the sample is 5.783838672193861
# The max RMS value is: 12.592579238116741
#
# audio_files/8039 - home depot samples 96k-1342.wav
# FILE:  8039 - home depot samples 96k-1342.wav
# audio_files/8039 - home depot samples 96k-1342.wav
# New Filename: 5.731988558523971 8039 - home depot samples 96k-1342.wav
# Sum of all the elements of the array: 3.381873249529143
# The length of the array is: 59
# The average RMS of the sample is 5.731988558523971
# The max RMS value is: 24.241283535957336
#
# audio_files/8039 - home depot samples 96k-1424.wav
# FILE:  8039 - home depot samples 96k-1424.wav
# audio_files/8039 - home depot samples 96k-1424.wav
# New Filename: 6.823100793347408 8039 - home depot samples 96k-1424.wav
# Sum of all the elements of the array: 3.4797814046071784
# The length of the array is: 51
# The average RMS of the sample is 6.823100793347408
# The max RMS value is: 15.442855656147003
#
# audio_files/8039 - home depot samples 96k-7055.wav
# FILE:  8039 - home depot samples 96k-7055.wav
# audio_files/8039 - home depot samples 96k-7055.wav
# New Filename: 6.578137118220311 8039 - home depot samples 96k-7055.wav
# Sum of all the elements of the array: 3.617975415021171
# The length of the array is: 55
# The average RMS of the sample is 6.578137118220311
# The max RMS value is: 11.476355604827404
#
# audio_files/8039 - home depot samples 96k-3233.wav
# FILE:  8039 - home depot samples 96k-3233.wav
# audio_files/8039 - home depot samples 96k-3233.wav
# New Filename: 7.476137446303248 8039 - home depot samples 96k-3233.wav
# Sum of all the elements of the array: 3.738068723151624
# The length of the array is: 50
# The average RMS of the sample is 7.476137446303248
# The max RMS value is: 19.881373271346092
#
# audio_files/8039 - home depot samples 96k-5642.wav
# FILE:  8039 - home depot samples 96k-5642.wav
# audio_files/8039 - home depot samples 96k-5642.wav
# New Filename: 7.206105690439242 8039 - home depot samples 96k-5642.wav
# Sum of all the elements of the array: 3.8192360159327983
# The length of the array is: 53
# The average RMS of the sample is 7.206105690439242
# The max RMS value is: 9.220728650689125
#
# audio_files/8039 - home depot samples 96k-3227.wav
# FILE:  8039 - home depot samples 96k-3227.wav
# audio_files/8039 - home depot samples 96k-3227.wav
# New Filename: 6.0078398073987005 8039 - home depot samples 96k-3227.wav
# Sum of all the elements of the array: 4.205487865179091
# The length of the array is: 70
# The average RMS of the sample is 6.0078398073987005
# The max RMS value is: 34.671902656555176
#
# audio_files/8039 - home depot samples 96k-4548.wav
# FILE:  8039 - home depot samples 96k-4548.wav
# audio_files/8039 - home depot samples 96k-4548.wav
# New Filename: 5.0511221857032655 8039 - home depot samples 96k-4548.wav
# Sum of all the elements of the array: 4.495498745275906
# The length of the array is: 89
# The average RMS of the sample is 5.0511221857032655
# The max RMS value is: 14.438936486840248
#
# audio_files/8039 - home depot samples 96k-5656.wav
# FILE:  8039 - home depot samples 96k-5656.wav
# audio_files/8039 - home depot samples 96k-5656.wav
# New Filename: 7.754460878761071 8039 - home depot samples 96k-5656.wav
# Sum of all the elements of the array: 4.730221136044253
# The length of the array is: 61
# The average RMS of the sample is 7.754460878761071
# The max RMS value is: 25.03175660967827
#
# audio_files/8039 - home depot samples 96k-2139.wav
# FILE:  8039 - home depot samples 96k-2139.wav
# audio_files/8039 - home depot samples 96k-2139.wav
# New Filename: 7.329110648480581 8039 - home depot samples 96k-2139.wav
# Sum of all the elements of the array: 4.8372130279971834
# The length of the array is: 66
# The average RMS of the sample is 7.329110648480581
# The max RMS value is: 15.175464563071728
#
# audio_files/8039 - home depot samples 96k-1430.wav
# FILE:  8039 - home depot samples 96k-1430.wav
# audio_files/8039 - home depot samples 96k-1430.wav
# New Filename: 9.338138327632063 8039 - home depot samples 96k-1430.wav
# Sum of all the elements of the array: 4.949213313644993
# The length of the array is: 53
# The average RMS of the sample is 9.338138327632063
# The max RMS value is: 14.433585107326508
#
# audio_files/8039 - home depot samples 96k-7041.wav
# FILE:  8039 - home depot samples 96k-7041.wav
# audio_files/8039 - home depot samples 96k-7041.wav
# New Filename: 9.854453007892456 8039 - home depot samples 96k-7041.wav
# Sum of all the elements of the array: 5.025771034025153
# The length of the array is: 51
# The average RMS of the sample is 9.854453007892456
# The max RMS value is: 9.49836801737547
#
# audio_files/8039 - home depot samples 96k-0048.wav
# FILE:  8039 - home depot samples 96k-0048.wav
# audio_files/8039 - home depot samples 96k-0048.wav
# New Filename: 8.092944756281309 8039 - home depot samples 96k-0048.wav
# Sum of all the elements of the array: 5.098555196457225
# The length of the array is: 63
# The average RMS of the sample is 8.092944756281309
# The max RMS value is: 12.742790393531322
#
# audio_files/8039 - home depot samples 96k-7727.wav
# FILE:  8039 - home depot samples 96k-7727.wav
# audio_files/8039 - home depot samples 96k-7727.wav
# New Filename: 9.670666003140841 8039 - home depot samples 96k-7727.wav
# Sum of all the elements of the array: 5.222159641696054
# The length of the array is: 54
# The average RMS of the sample is 9.670666003140841
# The max RMS value is: 15.193168073892593
#
# audio_files/8039 - home depot samples 96k-6439.wav
# FILE:  8039 - home depot samples 96k-6439.wav
# audio_files/8039 - home depot samples 96k-6439.wav
# New Filename: 8.440620742916593 8039 - home depot samples 96k-6439.wav
# Sum of all the elements of the array: 5.655215897754117
# The length of the array is: 67
# The average RMS of the sample is 8.440620742916593
# The max RMS value is: 69.31347399950027
#
# audio_files/8039 - home depot samples 96k-1356.wav
# FILE:  8039 - home depot samples 96k-1356.wav
# audio_files/8039 - home depot samples 96k-1356.wav
# New Filename: 10.488154033420443 8039 - home depot samples 96k-1356.wav
# Sum of all the elements of the array: 5.768484718381244
# The length of the array is: 55
# The average RMS of the sample is 10.488154033420443
# The max RMS value is: 16.49436354637146
#
# audio_files/8039 - home depot samples 96k-5130.wav
# FILE:  8039 - home depot samples 96k-5130.wav
# audio_files/8039 - home depot samples 96k-5130.wav
# New Filename: 11.451275465930983 8039 - home depot samples 96k-5130.wav
# Sum of all the elements of the array: 5.840150487624801
# The length of the array is: 51
# The average RMS of the sample is 11.451275465930983
# The max RMS value is: 10.01844648271799
#
# audio_files/8039 - home depot samples 96k-2887.wav
# FILE:  8039 - home depot samples 96k-2887.wav
# audio_files/8039 - home depot samples 96k-2887.wav
# New Filename: 11.590459543816884 8039 - home depot samples 96k-2887.wav
# Sum of all the elements of the array: 5.911134367346611
# The length of the array is: 51
# The average RMS of the sample is 11.590459543816884
# The max RMS value is: 9.53841395676136
#
# audio_files/8039 - home depot samples 96k-3541.wav
# FILE:  8039 - home depot samples 96k-3541.wav
# audio_files/8039 - home depot samples 96k-3541.wav
# New Filename: 11.923839074861643 8039 - home depot samples 96k-3541.wav
# Sum of all the elements of the array: 5.961919537430822
# The length of the array is: 50
# The average RMS of the sample is 11.923839074861643
# The max RMS value is: 7.4222576804459095
#
# audio_files/8039 - home depot samples 96k-7914.wav
# FILE:  8039 - home depot samples 96k-7914.wav
# audio_files/8039 - home depot samples 96k-7914.wav
# New Filename: 12.316666868162107 8039 - home depot samples 96k-7914.wav
# Sum of all the elements of the array: 6.158333434081054
# The length of the array is: 50
# The average RMS of the sample is 12.316666868162107
# The max RMS value is: 30.47475777566433
#
# audio_files/8039 - home depot samples 96k-5865.wav
# FILE:  8039 - home depot samples 96k-5865.wav
# audio_files/8039 - home depot samples 96k-5865.wav
# New Filename: 8.589042468977276 8039 - home depot samples 96k-5865.wav
# Sum of all the elements of the array: 6.52767227642273
# The length of the array is: 76
# The average RMS of the sample is 8.589042468977276
# The max RMS value is: 14.351442456245422
#
# audio_files/8039 - home depot samples 96k-5871.wav
# FILE:  8039 - home depot samples 96k-5871.wav
# audio_files/8039 - home depot samples 96k-5871.wav
# New Filename: 11.395626134728392 8039 - home depot samples 96k-5871.wav
# Sum of all the elements of the array: 6.837375680837035
# The length of the array is: 60
# The average RMS of the sample is 11.395626134728392
# The max RMS value is: 49.40835386514664
#
# audio_files/8039 - home depot samples 96k-0909.wav
# FILE:  8039 - home depot samples 96k-0909.wav
# audio_files/8039 - home depot samples 96k-0909.wav
# New Filename: 6.959068383292881 8039 - home depot samples 96k-0909.wav
# Sum of all the elements of the array: 7.02865906712581
# The length of the array is: 101
# The average RMS of the sample is 6.959068383292881
# The max RMS value is: 22.404352203011513
#
# audio_files/8039 - home depot samples 96k-7900.wav
# FILE:  8039 - home depot samples 96k-7900.wav
# audio_files/8039 - home depot samples 96k-7900.wav
# New Filename: 13.463060653451786 8039 - home depot samples 96k-7900.wav
# Sum of all the elements of the array: 7.404683359398482
# The length of the array is: 55
# The average RMS of the sample is 13.463060653451786
# The max RMS value is: 40.441807359457016
#
# audio_files/8039 - home depot samples 96k-2878.wav
# FILE:  8039 - home depot samples 96k-2878.wav
# audio_files/8039 - home depot samples 96k-2878.wav
# New Filename: 12.297248086017786 8039 - home depot samples 96k-2878.wav
# Sum of all the elements of the array: 7.624293813331028
# The length of the array is: 62
# The average RMS of the sample is 12.297248086017786
# The max RMS value is: 18.187033012509346
#
# audio_files/8039 - home depot samples 96k-1381.wav
# FILE:  8039 - home depot samples 96k-1381.wav
# audio_files/8039 - home depot samples 96k-1381.wav
# New Filename: 15.33996515708515 8039 - home depot samples 96k-1381.wav
# Sum of all the elements of the array: 7.669982578542575
# The length of the array is: 50
# The average RMS of the sample is 15.33996515708515
# The max RMS value is: 7.004500832408667
#
# audio_files/8039 - home depot samples 96k-7928.wav
# FILE:  8039 - home depot samples 96k-7928.wav
# audio_files/8039 - home depot samples 96k-7928.wav
# New Filename: 15.471034809706573 8039 - home depot samples 96k-7928.wav
# Sum of all the elements of the array: 7.7355174048532875
# The length of the array is: 50
# The average RMS of the sample is 15.471034809706573
# The max RMS value is: 10.787018574774265
#
# audio_files/8039 - home depot samples 96k-2850.wav
# FILE:  8039 - home depot samples 96k-2850.wav
# audio_files/8039 - home depot samples 96k-2850.wav
# New Filename: 13.603140596063593 8039 - home depot samples 96k-2850.wav
# Sum of all the elements of the array: 7.889821545716884
# The length of the array is: 58
# The average RMS of the sample is 13.603140596063593
# The max RMS value is: 13.052297756075859
#
# audio_files/8039 - home depot samples 96k-3596.wav
# FILE:  8039 - home depot samples 96k-3596.wav
# audio_files/8039 - home depot samples 96k-3596.wav
# New Filename: 15.628541553046743 8039 - home depot samples 96k-3596.wav
# Sum of all the elements of the array: 7.970556192053839
# The length of the array is: 51
# The average RMS of the sample is 15.628541553046743
# The max RMS value is: 11.702127754688263
#
# audio_files/8039 - home depot samples 96k-2688.wav
# FILE:  8039 - home depot samples 96k-2688.wav
# audio_files/8039 - home depot samples 96k-2688.wav
# New Filename: 14.674122529603912 8039 - home depot samples 96k-2688.wav
# Sum of all the elements of the array: 8.21750861657819
# The length of the array is: 56
# The average RMS of the sample is 14.674122529603912
# The max RMS value is: 34.631725400686264
#
# audio_files/8039 - home depot samples 96k-5681.wav
# FILE:  8039 - home depot samples 96k-5681.wav
# audio_files/8039 - home depot samples 96k-5681.wav
# New Filename: 12.221551076202115 8039 - home depot samples 96k-5681.wav
# Sum of all the elements of the array: 8.799516774865522
# The length of the array is: 72
# The average RMS of the sample is 12.221551076202115
# The max RMS value is: 54.13779988884926
#
# audio_files/8039 - home depot samples 96k-5859.wav
# FILE:  8039 - home depot samples 96k-5859.wav
# audio_files/8039 - home depot samples 96k-5859.wav
# New Filename: 17.804574193268188 8039 - home depot samples 96k-5859.wav
# Sum of all the elements of the array: 8.902287096634094
# The length of the array is: 50
# The average RMS of the sample is 17.804574193268188
# The max RMS value is: 17.370672896504402
#
# audio_files/8039 - home depot samples 96k-7096.wav
# FILE:  8039 - home depot samples 96k-7096.wav
# audio_files/8039 - home depot samples 96k-7096.wav
# New Filename: 17.93140431656643 8039 - home depot samples 96k-7096.wav
# Sum of all the elements of the array: 8.965702158283214
# The length of the array is: 50
# The average RMS of the sample is 17.93140431656643
# The max RMS value is: 10.310799814760685
#
# audio_files/8039 - home depot samples 96k-0921.wav
# FILE:  8039 - home depot samples 96k-0921.wav
# audio_files/8039 - home depot samples 96k-0921.wav
# New Filename: 11.890780018102843 8039 - home depot samples 96k-0921.wav
# Sum of all the elements of the array: 9.036992813758161
# The length of the array is: 76
# The average RMS of the sample is 11.890780018102843
# The max RMS value is: 3.3465437591075897
#
# audio_files/8039 - home depot samples 96k-6388.wav
# FILE:  8039 - home depot samples 96k-6388.wav
# audio_files/8039 - home depot samples 96k-6388.wav
# New Filename: 18.239781357287804 8039 - home depot samples 96k-6388.wav
# Sum of all the elements of the array: 9.119890678643902
# The length of the array is: 50
# The average RMS of the sample is 18.239781357287804
# The max RMS value is: 13.950553722679615
#
# audio_files/8039 - home depot samples 96k-7082.wav
# FILE:  8039 - home depot samples 96k-7082.wav
# audio_files/8039 - home depot samples 96k-7082.wav
# New Filename: 18.411784293512287 8039 - home depot samples 96k-7082.wav
# Sum of all the elements of the array: 9.205892146756144
# The length of the array is: 50
# The average RMS of the sample is 18.411784293512287
# The max RMS value is: 14.98679630458355
#
# audio_files/8039 - home depot samples 96k-0935.wav
# FILE:  8039 - home depot samples 96k-0935.wav
# audio_files/8039 - home depot samples 96k-0935.wav
# New Filename: 17.445027450543115 8039 - home depot samples 96k-0935.wav
# Sum of all the elements of the array: 9.245864548787852
# The length of the array is: 53
# The average RMS of the sample is 17.445027450543115
# The max RMS value is: 6.024656351655722
#
# audio_files/8039 - home depot samples 96k-5695.wav
# FILE:  8039 - home depot samples 96k-5695.wav
# audio_files/8039 - home depot samples 96k-5695.wav
# New Filename: 13.272847960072914 8039 - home depot samples 96k-5695.wav
# Sum of all the elements of the array: 9.423722051651769
# The length of the array is: 71
# The average RMS of the sample is 13.272847960072914
# The max RMS value is: 7.168285548686981
#
# audio_files/8039 - home depot samples 96k-2844.wav
# FILE:  8039 - home depot samples 96k-2844.wav
# audio_files/8039 - home depot samples 96k-2844.wav
# New Filename: 17.935868455201796 8039 - home depot samples 96k-2844.wav
# Sum of all the elements of the array: 9.506010281256952
# The length of the array is: 53
# The average RMS of the sample is 17.935868455201796
# The max RMS value is: 8.973777294158936
#
# audio_files/8039 - home depot samples 96k-3582.wav
# FILE:  8039 - home depot samples 96k-3582.wav
# audio_files/8039 - home depot samples 96k-3582.wav
# New Filename: 15.45297091931695 8039 - home depot samples 96k-3582.wav
# Sum of all the elements of the array: 9.735371679169678
# The length of the array is: 63
# The average RMS of the sample is 15.45297091931695
# The max RMS value is: 13.193592429161072
#
# audio_files/8039 - home depot samples 96k-1395.wav
# FILE:  8039 - home depot samples 96k-1395.wav
# audio_files/8039 - home depot samples 96k-1395.wav
# New Filename: 18.138415833647766 8039 - home depot samples 96k-1395.wav
# Sum of all the elements of the array: 9.976128708506272
# The length of the array is: 55
# The average RMS of the sample is 18.138415833647766
# The max RMS value is: 24.50740709900856
#
# audio_files/8039 - home depot samples 96k-0504.wav
# FILE:  8039 - home depot samples 96k-0504.wav
# audio_files/8039 - home depot samples 96k-0504.wav
# New Filename: 12.45982204734813 8039 - home depot samples 96k-0504.wav
# Sum of all the elements of the array: 10.466250519772428
# The length of the array is: 84
# The average RMS of the sample is 12.45982204734813
# The max RMS value is: 41.34788364171982
#
# audio_files/8039 - home depot samples 96k-6175.wav
# FILE:  8039 - home depot samples 96k-6175.wav
# audio_files/8039 - home depot samples 96k-6175.wav
# New Filename: 20.65266437034972 8039 - home depot samples 96k-6175.wav
# Sum of all the elements of the array: 10.532858828878357
# The length of the array is: 51
# The average RMS of the sample is 20.65266437034972
# The max RMS value is: 8.707461878657341
#
# audio_files/8039 - home depot samples 96k-2313.wav
# FILE:  8039 - home depot samples 96k-2313.wav
# audio_files/8039 - home depot samples 96k-2313.wav
# New Filename: 21.24823034758922 8039 - home depot samples 96k-2313.wav
# Sum of all the elements of the array: 10.62411517379461
# The length of the array is: 50
# The average RMS of the sample is 21.24823034758922
# The max RMS value is: 19.94984783232212
#
# audio_files/8039 - home depot samples 96k-4762.wav
# FILE:  8039 - home depot samples 96k-4762.wav
# audio_files/8039 - home depot samples 96k-4762.wav
# New Filename: 16.585758644858622 8039 - home depot samples 96k-4762.wav
# Sum of all the elements of the array: 10.780743119158105
# The length of the array is: 65
# The average RMS of the sample is 16.585758644858622
# The max RMS value is: 8.521171286702156
#
# audio_files/8039 - home depot samples 96k-4004.wav
# FILE:  8039 - home depot samples 96k-4004.wav
# audio_files/8039 - home depot samples 96k-4004.wav
# New Filename: 13.856780712484639 8039 - home depot samples 96k-4004.wav
# Sum of all the elements of the array: 11.223992377112557
# The length of the array is: 81
# The average RMS of the sample is 13.856780712484639
# The max RMS value is: 16.102006658911705
#
# audio_files/8039 - home depot samples 96k-2475.wav
# FILE:  8039 - home depot samples 96k-2475.wav
# audio_files/8039 - home depot samples 96k-2475.wav
# New Filename: 20.90165588021662 8039 - home depot samples 96k-2475.wav
# Sum of all the elements of the array: 11.286894175316974
# The length of the array is: 54
# The average RMS of the sample is 20.90165588021662
# The max RMS value is: 9.202484972774982
#
# audio_files/8039 - home depot samples 96k-6613.wav
# FILE:  8039 - home depot samples 96k-6613.wav
# audio_files/8039 - home depot samples 96k-6613.wav
# New Filename: 21.932727964398154 8039 - home depot samples 96k-6613.wav
# Sum of all the elements of the array: 11.40501854148704
# The length of the array is: 52
# The average RMS of the sample is 21.932727964398154
# The max RMS value is: 15.254642814397812
#
# audio_files/8039 - home depot samples 96k-0262.wav
# FILE:  8039 - home depot samples 96k-0262.wav
# audio_files/8039 - home depot samples 96k-0262.wav
# New Filename: 22.11049482585041 8039 - home depot samples 96k-0262.wav
# Sum of all the elements of the array: 11.497457309442213
# The length of the array is: 52
# The average RMS of the sample is 22.11049482585041
# The max RMS value is: 13.117081485688686
#
# audio_files/8039 - home depot samples 96k-1168.wav
# FILE:  8039 - home depot samples 96k-1168.wav
# audio_files/8039 - home depot samples 96k-1168.wav
# New Filename: 8.877100712753448 8039 - home depot samples 96k-1168.wav
# Sum of all the elements of the array: 11.629001933707016
# The length of the array is: 131
# The average RMS of the sample is 8.877100712753448
# The max RMS value is: 4.937805701047182
#
# audio_files/8039 - home depot samples 96k-6607.wav
# FILE:  8039 - home depot samples 96k-6607.wav
# audio_files/8039 - home depot samples 96k-6607.wav
# New Filename: 19.187780357445156 8039 - home depot samples 96k-6607.wav
# Sum of all the elements of the array: 11.896423821615997
# The length of the array is: 62
# The average RMS of the sample is 19.187780357445156
# The max RMS value is: 14.784219674766064
#
# audio_files/8039 - home depot samples 96k-7519.wav
# FILE:  8039 - home depot samples 96k-7519.wav
# audio_files/8039 - home depot samples 96k-7519.wav
# New Filename: 23.81670697115862 8039 - home depot samples 96k-7519.wav
# Sum of all the elements of the array: 12.146520555290897
# The length of the array is: 51
# The average RMS of the sample is 23.81670697115862
# The max RMS value is: 50.98331347107887
#
# audio_files/8039 - home depot samples 96k-0276.wav
# FILE:  8039 - home depot samples 96k-0276.wav
# audio_files/8039 - home depot samples 96k-0276.wav
# New Filename: 22.593295207469026 8039 - home depot samples 96k-0276.wav
# Sum of all the elements of the array: 12.200379412033273
# The length of the array is: 54
# The average RMS of the sample is 22.593295207469026
# The max RMS value is: 7.052933797240257
#
# audio_files/8039 - home depot samples 96k-4010.wav
# FILE:  8039 - home depot samples 96k-4010.wav
# audio_files/8039 - home depot samples 96k-4010.wav
# New Filename: 23.15851666915152 8039 - home depot samples 96k-4010.wav
# Sum of all the elements of the array: 12.274013834650306
# The length of the array is: 53
# The average RMS of the sample is 23.15851666915152
# The max RMS value is: 8.240299299359322
#
# audio_files/8039 - home depot samples 96k-2461.wav
# FILE:  8039 - home depot samples 96k-2461.wav
# audio_files/8039 - home depot samples 96k-2461.wav
# New Filename: 22.884466312733 8039 - home depot samples 96k-2461.wav
# Sum of all the elements of the array: 12.35761180887582
# The length of the array is: 54
# The average RMS of the sample is 22.884466312733
# The max RMS value is: 7.66151025891304
#
# audio_files/8039 - home depot samples 96k-2307.wav
# FILE:  8039 - home depot samples 96k-2307.wav
# audio_files/8039 - home depot samples 96k-2307.wav
# New Filename: 24.477156783596346 8039 - home depot samples 96k-2307.wav
# Sum of all the elements of the array: 12.483349959634136
# The length of the array is: 51
# The average RMS of the sample is 24.477156783596346
# The max RMS value is: 18.49948801100254
#
# audio_files/8039 - home depot samples 96k-5468.wav
# FILE:  8039 - home depot samples 96k-5468.wav
# audio_files/8039 - home depot samples 96k-5468.wav
# New Filename: 20.652120393893373 8039 - home depot samples 96k-5468.wav
# Sum of all the elements of the array: 12.597793440274957
# The length of the array is: 61
# The average RMS of the sample is 20.652120393893373
# The max RMS value is: 9.150338359177113
#
# audio_files/8039 - home depot samples 96k-4776.wav
# FILE:  8039 - home depot samples 96k-4776.wav
# audio_files/8039 - home depot samples 96k-4776.wav
# New Filename: 23.055994890191748 8039 - home depot samples 96k-4776.wav
# Sum of all the elements of the array: 12.68079718960546
# The length of the array is: 55
# The average RMS of the sample is 23.055994890191748
# The max RMS value is: 7.513686548918486
#
# audio_files/8039 - home depot samples 96k-3019.wav
# FILE:  8039 - home depot samples 96k-3019.wav
# audio_files/8039 - home depot samples 96k-3019.wav
# New Filename: 25.50407326507948 8039 - home depot samples 96k-3019.wav
# Sum of all the elements of the array: 12.75203663253974
# The length of the array is: 50
# The average RMS of the sample is 25.50407326507948
# The max RMS value is: 10.994737036526203
#
# audio_files/8039 - home depot samples 96k-0510.wav
# FILE:  8039 - home depot samples 96k-0510.wav
# audio_files/8039 - home depot samples 96k-0510.wav
# New Filename: 13.701707913700995 8039 - home depot samples 96k-0510.wav
# Sum of all the elements of the array: 13.290656676289965
# The length of the array is: 97
# The average RMS of the sample is 13.701707913700995
# The max RMS value is: 43.75213384628296
#
# audio_files/8039 - home depot samples 96k-6161.wav
# FILE:  8039 - home depot samples 96k-6161.wav
# audio_files/8039 - home depot samples 96k-6161.wav
# New Filename: 25.736797791786735 8039 - home depot samples 96k-6161.wav
# Sum of all the elements of the array: 13.383134851729103
# The length of the array is: 52
# The average RMS of the sample is 25.736797791786735
# The max RMS value is: 13.413985259830952
#
# audio_files/8039 - home depot samples 96k-4986.wav
# FILE:  8039 - home depot samples 96k-4986.wav
# audio_files/8039 - home depot samples 96k-4986.wav
# New Filename: 21.437653798349167 8039 - home depot samples 96k-4986.wav
# Sum of all the elements of the array: 13.505721892959976
# The length of the array is: 63
# The average RMS of the sample is 21.437653798349167
# The max RMS value is: 7.174684666097164
#
# audio_files/8039 - home depot samples 96k-5440.wav
# FILE:  8039 - home depot samples 96k-5440.wav
# audio_files/8039 - home depot samples 96k-5440.wav
# New Filename: 26.63881477247887 8039 - home depot samples 96k-5440.wav
# Sum of all the elements of the array: 13.585795533964223
# The length of the array is: 51
# The average RMS of the sample is 26.63881477247887
# The max RMS value is: 11.777440086007118
#
# audio_files/8039 - home depot samples 96k-3031.wav
# FILE:  8039 - home depot samples 96k-3031.wav
# audio_files/8039 - home depot samples 96k-3031.wav
# New Filename: 21.831365487480557 8039 - home depot samples 96k-3031.wav
# Sum of all the elements of the array: 13.972073911987556
# The length of the array is: 64
# The average RMS of the sample is 21.831365487480557
# The max RMS value is: 32.54298493266106
#
# audio_files/8039 - home depot samples 96k-0538.wav
# FILE:  8039 - home depot samples 96k-0538.wav
# audio_files/8039 - home depot samples 96k-0538.wav
# New Filename: 24.808065281409743 8039 - home depot samples 96k-0538.wav
# Sum of all the elements of the array: 14.140597210403552
# The length of the array is: 57
# The average RMS of the sample is 24.808065281409743
# The max RMS value is: 22.609084844589233
#
# audio_files/8039 - home depot samples 96k-7257.wav
# FILE:  8039 - home depot samples 96k-7257.wav
# audio_files/8039 - home depot samples 96k-7257.wav
# New Filename: 28.61638324976222 8039 - home depot samples 96k-7257.wav
# Sum of all the elements of the array: 14.59435545737873
# The length of the array is: 51
# The average RMS of the sample is 28.61638324976222
# The max RMS value is: 82.45044201612473
#
# audio_files/8039 - home depot samples 96k-6149.wav
# FILE:  8039 - home depot samples 96k-6149.wav
# audio_files/8039 - home depot samples 96k-6149.wav
# New Filename: 29.288588631503444 8039 - home depot samples 96k-6149.wav
# Sum of all the elements of the array: 14.64429431575172
# The length of the array is: 50
# The average RMS of the sample is 29.288588631503444
# The max RMS value is: 7.17630609869957
#
# audio_files/8039 - home depot samples 96k-1626.wav
# FILE:  8039 - home depot samples 96k-1626.wav
# audio_files/8039 - home depot samples 96k-1626.wav
# New Filename: 15.898730948603806 8039 - home depot samples 96k-1626.wav
# Sum of all the elements of the array: 14.785819782201541
# The length of the array is: 93
# The average RMS of the sample is 15.898730948603806
# The max RMS value is: 13.248813338577747
#
# audio_files/8039 - home depot samples 96k-1140.wav
# FILE:  8039 - home depot samples 96k-1140.wav
# audio_files/8039 - home depot samples 96k-1140.wav
# New Filename: 29.775703032761356 8039 - home depot samples 96k-1140.wav
# Sum of all the elements of the array: 14.88785151638068
# The length of the array is: 50
# The average RMS of the sample is 29.775703032761356
# The max RMS value is: 20.534327253699303
#
# audio_files/8039 - home depot samples 96k-7531.wav
# FILE:  8039 - home depot samples 96k-7531.wav
# audio_files/8039 - home depot samples 96k-7531.wav
# New Filename: 28.311736492603213 8039 - home depot samples 96k-7531.wav
# Sum of all the elements of the array: 15.288337706005736
# The length of the array is: 54
# The average RMS of the sample is 28.311736492603213
# The max RMS value is: 44.57694664597511
#
# audio_files/8039 - home depot samples 96k-3757.wav
# FILE:  8039 - home depot samples 96k-3757.wav
# audio_files/8039 - home depot samples 96k-3757.wav
# New Filename: 30.72639417700461 8039 - home depot samples 96k-3757.wav
# Sum of all the elements of the array: 15.363197088502307
# The length of the array is: 50
# The average RMS of the sample is 30.72639417700461
# The max RMS value is: 12.116601690649986
#
# audio_files/8039 - home depot samples 96k-4038.wav
# FILE:  8039 - home depot samples 96k-4038.wav
# audio_files/8039 - home depot samples 96k-4038.wav
# New Filename: 25.905699358589462 8039 - home depot samples 96k-4038.wav
# Sum of all the elements of the array: 15.543419615153677
# The length of the array is: 60
# The average RMS of the sample is 25.905699358589462
# The max RMS value is: 12.435668148100376
#
# audio_files/8039 - home depot samples 96k-5326.wav
# FILE:  8039 - home depot samples 96k-5326.wav
# audio_files/8039 - home depot samples 96k-5326.wav
# New Filename: 22.044616571081303 8039 - home depot samples 96k-5326.wav
# Sum of all the elements of the array: 15.872123931178537
# The length of the array is: 72
# The average RMS of the sample is 22.044616571081303
# The max RMS value is: 37.52605617046356
#
# audio_files/8039 - home depot samples 96k-2449.wav
# FILE:  8039 - home depot samples 96k-2449.wav
# audio_files/8039 - home depot samples 96k-2449.wav
# New Filename: 28.606760742319814 8039 - home depot samples 96k-2449.wav
# Sum of all the elements of the array: 16.019786015699097
# The length of the array is: 56
# The average RMS of the sample is 28.606760742319814
# The max RMS value is: 22.784680128097534
#
# audio_files/8039 - home depot samples 96k-3743.wav
# FILE:  8039 - home depot samples 96k-3743.wav
# audio_files/8039 - home depot samples 96k-3743.wav
# New Filename: 29.840284301143168 8039 - home depot samples 96k-3743.wav
# Sum of all the elements of the array: 16.11375352261731
# The length of the array is: 54
# The average RMS of the sample is 29.840284301143168
# The max RMS value is: 9.32598952203989
#
# audio_files/8039 - home depot samples 96k-5332.wav
# FILE:  8039 - home depot samples 96k-5332.wav
# audio_files/8039 - home depot samples 96k-5332.wav
# New Filename: 14.648524170254243 8039 - home depot samples 96k-5332.wav
# Sum of all the elements of the array: 16.699317554089838
# The length of the array is: 114
# The average RMS of the sample is 14.648524170254243
# The max RMS value is: 44.62464898824692
#
# audio_files/8039 - home depot samples 96k-1154.wav
# FILE:  8039 - home depot samples 96k-1154.wav
# audio_files/8039 - home depot samples 96k-1154.wav
# New Filename: 30.92307130497916 8039 - home depot samples 96k-1154.wav
# Sum of all the elements of the array: 17.007689217738537
# The length of the array is: 55
# The average RMS of the sample is 30.92307130497916
# The max RMS value is: 52.463412284851074
#
# audio_files/8039 - home depot samples 96k-7525.wav
# FILE:  8039 - home depot samples 96k-7525.wav
# audio_files/8039 - home depot samples 96k-7525.wav
# New Filename: 32.64617663136861 8039 - home depot samples 96k-7525.wav
# Sum of all the elements of the array: 17.302473614625363
# The length of the array is: 53
# The average RMS of the sample is 32.64617663136861
# The max RMS value is: 54.88777905702591
#
# audio_files/8039 - home depot samples 96k-7243.wav
# FILE:  8039 - home depot samples 96k-7243.wav
# audio_files/8039 - home depot samples 96k-7243.wav
# New Filename: 34.77483782860369 8039 - home depot samples 96k-7243.wav
# Sum of all the elements of the array: 17.387418914301843
# The length of the array is: 50
# The average RMS of the sample is 34.77483782860369
# The max RMS value is: 14.524680562317371
#
# audio_files/8039 - home depot samples 96k-1632.wav
# FILE:  8039 - home depot samples 96k-1632.wav
# audio_files/8039 - home depot samples 96k-1632.wav
# New Filename: 34.838919315035646 8039 - home depot samples 96k-1632.wav
# Sum of all the elements of the array: 17.419459657517823
# The length of the array is: 50
# The average RMS of the sample is 34.838919315035646
# The max RMS value is: 5.5865151807665825
#
# audio_files/8039 - home depot samples 96k-4992.wav
# FILE:  8039 - home depot samples 96k-4992.wav
# audio_files/8039 - home depot samples 96k-4992.wav
# New Filename: 31.298643803386287 8039 - home depot samples 96k-4992.wav
# Sum of all the elements of the array: 17.52724052989632
# The length of the array is: 56
# The average RMS of the sample is 31.298643803386287
# The max RMS value is: 8.576160296797752
#
# audio_files/8039 - home depot samples 96k-5454.wav
# FILE:  8039 - home depot samples 96k-5454.wav
# audio_files/8039 - home depot samples 96k-5454.wav
# New Filename: 23.62132657846039 8039 - home depot samples 96k-5454.wav
# Sum of all the elements of the array: 18.1884214654145
# The length of the array is: 77
# The average RMS of the sample is 23.62132657846039
# The max RMS value is: 46.99791595339775
#
# audio_files/8039 - home depot samples 96k-3025.wav
# FILE:  8039 - home depot samples 96k-3025.wav
# audio_files/8039 - home depot samples 96k-3025.wav
# New Filename: 28.100287024525095 8039 - home depot samples 96k-3025.wav
# Sum of all the elements of the array: 18.82719230643181
# The length of the array is: 67
# The average RMS of the sample is 28.100287024525095
# The max RMS value is: 54.69198897480965
#
# audio_files/8039 - home depot samples 96k-4979.wav
# FILE:  8039 - home depot samples 96k-4979.wav
# audio_files/8039 - home depot samples 96k-4979.wav
# New Filename: 35.68048944157647 8039 - home depot samples 96k-4979.wav
# Sum of all the elements of the array: 18.910659404035528
# The length of the array is: 53
# The average RMS of the sample is 35.68048944157647
# The max RMS value is: 8.910429663956165
#
# audio_files/8039 - home depot samples 96k-1801.wav
# FILE:  8039 - home depot samples 96k-1801.wav
# audio_files/8039 - home depot samples 96k-1801.wav
# New Filename: 22.363812376078222 8039 - home depot samples 96k-1801.wav
# Sum of all the elements of the array: 21.02198363351353
# The length of the array is: 94
# The average RMS of the sample is 22.363812376078222
# The max RMS value is: 167.2382950782776
#
# audio_files/8039 - home depot samples 96k-6808.wav
# FILE:  8039 - home depot samples 96k-6808.wav
# audio_files/8039 - home depot samples 96k-6808.wav
# New Filename: 40.59718131564485 8039 - home depot samples 96k-6808.wav
# Sum of all the elements of the array: 21.110534284135323
# The length of the array is: 52
# The average RMS of the sample is 40.59718131564485
# The max RMS value is: 10.1157920435071
#
# audio_files/8039 - home depot samples 96k-3970.wav
# FILE:  8039 - home depot samples 96k-3970.wav
# audio_files/8039 - home depot samples 96k-3970.wav
# New Filename: 16.19507048650957 8039 - home depot samples 96k-3970.wav
# Sum of all the elements of the array: 21.863345156787922
# The length of the array is: 135
# The average RMS of the sample is 16.19507048650957
# The max RMS value is: 58.71129408478737
#
# audio_files/8039 - home depot samples 96k-3964.wav
# FILE:  8039 - home depot samples 96k-3964.wav
# audio_files/8039 - home depot samples 96k-3964.wav
# New Filename: 44.240922139569506 8039 - home depot samples 96k-3964.wav
# Sum of all the elements of the array: 22.120461069784753
# The length of the array is: 50
# The average RMS of the sample is 44.240922139569506
# The max RMS value is: 50.25477334856987
#
# audio_files/8039 - home depot samples 96k-1815.wav
# FILE:  8039 - home depot samples 96k-1815.wav
# audio_files/8039 - home depot samples 96k-1815.wav
# New Filename: 22.517910713712162 8039 - home depot samples 96k-1815.wav
# Sum of all the elements of the array: 24.094164463672016
# The length of the array is: 107
# The average RMS of the sample is 22.517910713712162
# The max RMS value is: 173.70125651359558
#
# audio_files/8039 - home depot samples 96k-7294.wav
# FILE:  8039 - home depot samples 96k-7294.wav
# audio_files/8039 - home depot samples 96k-7294.wav
# New Filename: 45.69446969167447 8039 - home depot samples 96k-7294.wav
# Sum of all the elements of the array: 24.21806893658747
# The length of the array is: 53
# The average RMS of the sample is 45.69446969167447
# The max RMS value is: 14.668281190097332
#
# audio_files/8039 - home depot samples 96k-4945.wav
# FILE:  8039 - home depot samples 96k-4945.wav
# audio_files/8039 - home depot samples 96k-4945.wav
# New Filename: 18.661179891076742 8039 - home depot samples 96k-4945.wav
# Sum of all the elements of the array: 25.37920465186437
# The length of the array is: 136
# The average RMS of the sample is 18.661179891076742
# The max RMS value is: 92.92718768119812
#
# audio_files/8039 - home depot samples 96k-5483.wav
# FILE:  8039 - home depot samples 96k-5483.wav
# audio_files/8039 - home depot samples 96k-5483.wav
# New Filename: 50.91768269027644 8039 - home depot samples 96k-5483.wav
# Sum of all the elements of the array: 25.45884134513822
# The length of the array is: 50
# The average RMS of the sample is 50.91768269027644
# The max RMS value is: 12.236757203936577
#
# audio_files/8039 - home depot samples 96k-3794.wav
# FILE:  8039 - home depot samples 96k-3794.wav
# audio_files/8039 - home depot samples 96k-3794.wav
# New Filename: 32.45822540613046 8039 - home depot samples 96k-3794.wav
# Sum of all the elements of the array: 25.966580324904367
# The length of the array is: 80
# The average RMS of the sample is 32.45822540613046
# The max RMS value is: 26.70859545469284
#
# audio_files/8039 - home depot samples 96k-6834.wav
# FILE:  8039 - home depot samples 96k-6834.wav
# audio_files/8039 - home depot samples 96k-6834.wav
# New Filename: 47.4827402237131 8039 - home depot samples 96k-6834.wav
# Sum of all the elements of the array: 26.115507123042203
# The length of the array is: 55
# The average RMS of the sample is 47.4827402237131
# The max RMS value is: 14.157474040985107
#
# audio_files/8039 - home depot samples 96k-1183.wav
# FILE:  8039 - home depot samples 96k-1183.wav
# audio_files/8039 - home depot samples 96k-1183.wav
# New Filename: 48.415797334606964 8039 - home depot samples 96k-1183.wav
# Sum of all the elements of the array: 26.14453056068776
# The length of the array is: 54
# The average RMS of the sample is 48.415797334606964
# The max RMS value is: 4.277742002159357
#
# audio_files/8039 - home depot samples 96k-6820.wav
# FILE:  8039 - home depot samples 96k-6820.wav
# audio_files/8039 - home depot samples 96k-6820.wav
# New Filename: 50.46041331369951 8039 - home depot samples 96k-6820.wav
# Sum of all the elements of the array: 26.23941492312375
# The length of the array is: 52
# The average RMS of the sample is 50.46041331369951
# The max RMS value is: 10.745270177721977
#
# audio_files/8039 - home depot samples 96k-0289.wav
# FILE:  8039 - home depot samples 96k-0289.wav
# audio_files/8039 - home depot samples 96k-0289.wav
# New Filename: 41.94251704348157 8039 - home depot samples 96k-0289.wav
# Sum of all the elements of the array: 26.42378573739339
# The length of the array is: 63
# The average RMS of the sample is 41.94251704348157
# The max RMS value is: 34.97806191444397
#
# ...
# Sum of all the elements of the array: 672.1918122292263
# The length of the array is: 52
# The average RMS of the sample is 1292.6765619792814
# The max RMS value is: 9.658439084887505
#
# audio_files/8039 - home depot samples 96k-2212.wav
# FILE:  8039 - home depot samples 96k-2212.wav
# audio_files/8039 - home depot samples 96k-2212.wav
# New Filename: 1003.6477728313322 8039 - home depot samples 96k-2212.wav
# Sum of all the elements of the array: 672.4440077969925
# The length of the array is: 67
# The average RMS of the sample is 1003.6477728313322
# The max RMS value is: 35.3296734392643
#
# audio_files/8039 - home depot samples 96k-4663.wav
# FILE:  8039 - home depot samples 96k-4663.wav
# audio_files/8039 - home depot samples 96k-4663.wav
# New Filename: 1345.0313606616535 8039 - home depot samples 96k-4663.wav
# Sum of all the elements of the array: 672.5156803308267
# The length of the array is: 50
# The average RMS of the sample is 1345.0313606616535
# The max RMS value is: 10.177048854529858
#
# audio_files/8039 - home depot samples 96k-0405.wav
# FILE:  8039 - home depot samples 96k-0405.wav
# audio_files/8039 - home depot samples 96k-0405.wav
# New Filename: 666.0148996918817 8039 - home depot samples 96k-0405.wav
# Sum of all the elements of the array: 672.6750486888005
# The length of the array is: 101
# The average RMS of the sample is 666.0148996918817
# The max RMS value is: 13.510032556951046
#
# audio_files/8039 - home depot samples 96k-6074.wav
# FILE:  8039 - home depot samples 96k-6074.wav
# audio_files/8039 - home depot samples 96k-6074.wav
# New Filename: 1293.7679205584554 8039 - home depot samples 96k-6074.wav
# Sum of all the elements of the array: 672.7593186903969
# The length of the array is: 52
# The average RMS of the sample is 1293.7679205584554
# The max RMS value is: 9.828784503042698
#
# audio_files/8039 - home depot samples 96k-1684.wav
# FILE:  8039 - home depot samples 96k-1684.wav
# audio_files/8039 - home depot samples 96k-1684.wav
# New Filename: 1345.7907323839638 8039 - home depot samples 96k-1684.wav
# Sum of all the elements of the array: 672.8953661919819
# The length of the array is: 50
# The average RMS of the sample is 1345.7907323839638
# The max RMS value is: 24.517839774489403
#
# audio_files/8039 - home depot samples 96k-4924.wav
# FILE:  8039 - home depot samples 96k-4924.wav
# audio_files/8039 - home depot samples 96k-4924.wav
# New Filename: 1246.2310515366967 8039 - home depot samples 96k-4924.wav
# Sum of all the elements of the array: 672.9647678298162
# The length of the array is: 54
# The average RMS of the sample is 1246.2310515366967
# The max RMS value is: 7.4018752202391624
#
# audio_files/8039 - home depot samples 96k-3093.wav
# FILE:  8039 - home depot samples 96k-3093.wav
# audio_files/8039 - home depot samples 96k-3093.wav
# New Filename: 1346.9457071780855 8039 - home depot samples 96k-3093.wav
# Sum of all the elements of the array: 673.4728535890428
# The length of the array is: 50
# The average RMS of the sample is 1346.9457071780855
# The max RMS value is: 92.38302707672119
#
# audio_files/8039 - home depot samples 96k-5384.wav
# FILE:  8039 - home depot samples 96k-5384.wav
# audio_files/8039 - home depot samples 96k-5384.wav
# New Filename: 654.1828892870767 8039 - home depot samples 96k-5384.wav
# Sum of all the elements of the array: 673.808375965689
# The length of the array is: 103
# The average RMS of the sample is 654.1828892870767
# The max RMS value is: 10.507006198167801
#
# audio_files/8039 - home depot samples 96k-6855.wav
# FILE:  8039 - home depot samples 96k-6855.wav
# audio_files/8039 - home depot samples 96k-6855.wav
# New Filename: 448.8254465372137 8039 - home depot samples 96k-6855.wav
# Sum of all the elements of the array: 677.7264242711926
# The length of the array is: 151
# The average RMS of the sample is 448.8254465372137
# The max RMS value is: 119.68975514173508
#
# audio_files/8039 - home depot samples 96k-7593.wav
# FILE:  8039 - home depot samples 96k-7593.wav
# audio_files/8039 - home depot samples 96k-7593.wav
# New Filename: 1232.423778274009 8039 - home depot samples 96k-7593.wav
# Sum of all the elements of the array: 677.8330780507049
# The length of the array is: 55
# The average RMS of the sample is 1232.423778274009
# The max RMS value is: 11.496479623019695
#
# audio_files/8039 - home depot samples 96k-6699.wav
# FILE:  8039 - home depot samples 96k-6699.wav
# audio_files/8039 - home depot samples 96k-6699.wav
# New Filename: 1255.497101481736 8039 - home depot samples 96k-6699.wav
# Sum of all the elements of the array: 677.9684348001374
# The length of the array is: 54
# The average RMS of the sample is 1255.497101481736
# The max RMS value is: 12.936883606016636
#
# audio_files/8039 - home depot samples 96k-6841.wav
# FILE:  8039 - home depot samples 96k-6841.wav
# audio_files/8039 - home depot samples 96k-6841.wav
# New Filename: 1356.0957500705968 8039 - home depot samples 96k-6841.wav
# Sum of all the elements of the array: 678.0478750352984
# The length of the array is: 50
# The average RMS of the sample is 1356.0957500705968
# The max RMS value is: 10.537458583712578
#
# audio_files/8039 - home depot samples 96k-7587.wav
# FILE:  8039 - home depot samples 96k-7587.wav
# audio_files/8039 - home depot samples 96k-7587.wav
# New Filename: 1279.9864962280737 8039 - home depot samples 96k-7587.wav
# Sum of all the elements of the array: 678.3928430008791
# The length of the array is: 53
# The average RMS of the sample is 1279.9864962280737
# The max RMS value is: 47.00236767530441
#
# audio_files/8039 - home depot samples 96k-5390.wav
# FILE:  8039 - home depot samples 96k-5390.wav
# audio_files/8039 - home depot samples 96k-5390.wav
# New Filename: 1130.848292322542 8039 - home depot samples 96k-5390.wav
# Sum of all the elements of the array: 678.5089753935251
# The length of the array is: 60
# The average RMS of the sample is 1130.848292322542
# The max RMS value is: 8.74984823167324
#
# audio_files/8039 - home depot samples 96k-3939.wav
# FILE:  8039 - home depot samples 96k-3939.wav
# audio_files/8039 - home depot samples 96k-3939.wav
# New Filename: 1330.537953577188 8039 - home depot samples 96k-3939.wav
# Sum of all the elements of the array: 678.5743563243659
# The length of the array is: 51
# The average RMS of the sample is 1330.537953577188
# The max RMS value is: 8.31036176532507
#
# audio_files/8039 - home depot samples 96k-4930.wav
# FILE:  8039 - home depot samples 96k-4930.wav
# audio_files/8039 - home depot samples 96k-4930.wav
# New Filename: 1190.9981205540007 8039 - home depot samples 96k-4930.wav
# Sum of all the elements of the array: 678.8689287157804
# The length of the array is: 57
# The average RMS of the sample is 1190.9981205540007
# The max RMS value is: 29.173145070672035
#
# audio_files/8039 - home depot samples 96k-2399.wav
# FILE:  8039 - home depot samples 96k-2399.wav
# audio_files/8039 - home depot samples 96k-2399.wav
# New Filename: 1357.9597466070989 8039 - home depot samples 96k-2399.wav
# Sum of all the elements of the array: 678.9798733035494
# The length of the array is: 50
# The average RMS of the sample is 1357.9597466070989
# The max RMS value is: 17.945734784007072
#
# audio_files/8039 - home depot samples 96k-3087.wav
# FILE:  8039 - home depot samples 96k-3087.wav
# audio_files/8039 - home depot samples 96k-3087.wav
# New Filename: 1257.9066060929542 8039 - home depot samples 96k-3087.wav
# Sum of all the elements of the array: 679.2695672901953
# The length of the array is: 54
# The average RMS of the sample is 1257.9066060929542
# The max RMS value is: 49.34362694621086
#
# audio_files/8039 - home depot samples 96k-1848.wav
# FILE:  8039 - home depot samples 96k-1848.wav
# audio_files/8039 - home depot samples 96k-1848.wav
# New Filename: 1331.9575972326973 8039 - home depot samples 96k-1848.wav
# Sum of all the elements of the array: 679.2983745886756
# The length of the array is: 51
# The average RMS of the sample is 1331.9575972326973
# The max RMS value is: 3.5814850125461817
#
# audio_files/8039 - home depot samples 96k-1690.wav
# FILE:  8039 - home depot samples 96k-1690.wav
# audio_files/8039 - home depot samples 96k-1690.wav
# New Filename: 1358.7127064436097 8039 - home depot samples 96k-1690.wav
# Sum of all the elements of the array: 679.3563532218049
# The length of the array is: 50
# The average RMS of the sample is 1358.7127064436097
# The max RMS value is: 8.59851110726595
#
# audio_files/8039 - home depot samples 96k-4918.wav
# FILE:  8039 - home depot samples 96k-4918.wav
# audio_files/8039 - home depot samples 96k-4918.wav
# New Filename: 572.4199455512306 8039 - home depot samples 96k-4918.wav
# Sum of all the elements of the array: 681.1797352059644
# The length of the array is: 119
# The average RMS of the sample is 572.4199455512306
# The max RMS value is: 98.80371391773224
#
# audio_files/8039 - home depot samples 96k-1860.wav
# FILE:  8039 - home depot samples 96k-1860.wav
# audio_files/8039 - home depot samples 96k-1860.wav
# New Filename: 567.7455020807358 8039 - home depot samples 96k-1860.wav
# Sum of all the elements of the array: 681.2946024968829
# The length of the array is: 120
# The average RMS of the sample is 567.7455020807358
# The max RMS value is: 3.0414655338972807
#
# audio_files/8039 - home depot samples 96k-6869.wav
# FILE:  8039 - home depot samples 96k-6869.wav
# audio_files/8039 - home depot samples 96k-6869.wav
# New Filename: 1336.0240734027957 8039 - home depot samples 96k-6869.wav
# Sum of all the elements of the array: 681.3722774354258
# The length of the array is: 51
# The average RMS of the sample is 1336.0240734027957
# The max RMS value is: 10.04613284021616
#
# audio_files/8039 - home depot samples 96k-3911.wav
# FILE:  8039 - home depot samples 96k-3911.wav
# audio_files/8039 - home depot samples 96k-3911.wav
# New Filename: 1099.2766062330616 8039 - home depot samples 96k-3911.wav
# Sum of all the elements of the array: 681.5514958644982
# The length of the array is: 62
# The average RMS of the sample is 1099.2766062330616
# The max RMS value is: 12.666381895542145
#
# audio_files/8039 - home depot samples 96k-3905.wav
# FILE:  8039 - home depot samples 96k-3905.wav
# audio_files/8039 - home depot samples 96k-3905.wav
# New Filename: 1082.0475747350172 8039 - home depot samples 96k-3905.wav
# Sum of all the elements of the array: 681.6899720830608
# The length of the array is: 63
# The average RMS of the sample is 1082.0475747350172
# The max RMS value is: 8.594215847551823
#
# audio_files/8039 - home depot samples 96k-1874.wav
# FILE:  8039 - home depot samples 96k-1874.wav
# audio_files/8039 - home depot samples 96k-1874.wav
# New Filename: 1217.3679139649691 8039 - home depot samples 96k-1874.wav
# Sum of all the elements of the array: 681.7260318203827
# The length of the array is: 56
# The average RMS of the sample is 1217.3679139649691
# The max RMS value is: 3.311633365228772
#
# audio_files/8039 - home depot samples 96k-3050.wav
# FILE:  8039 - home depot samples 96k-3050.wav
# audio_files/8039 - home depot samples 96k-3050.wav
# New Filename: 1363.6352667135784 8039 - home depot samples 96k-3050.wav
# Sum of all the elements of the array: 681.8176333567892
# The length of the array is: 50
# The average RMS of the sample is 1363.6352667135784
# The max RMS value is: 13.618397526443005
#
# audio_files/8039 - home depot samples 96k-5421.wav
# FILE:  8039 - home depot samples 96k-5421.wav
# audio_files/8039 - home depot samples 96k-5421.wav
# New Filename: 246.3475704532616 8039 - home depot samples 96k-5421.wav
# Sum of all the elements of the array: 707.0175272008609
# The length of the array is: 287
# The average RMS of the sample is 246.3475704532616
# The max RMS value is: 269.82995867729187
#
# audio_files/8039 - home depot samples 96k-1647.wav
# FILE:  8039 - home depot samples 96k-1647.wav
# audio_files/8039 - home depot samples 96k-1647.wav
# New Filename: 1386.4748739412576 8039 - home depot samples 96k-1647.wav
# Sum of all the elements of the array: 707.1021857100413
# The length of the array is: 51
# The average RMS of the sample is 1386.4748739412576
# The max RMS value is: 13.794131577014923
#
# audio_files/8039 - home depot samples 96k-6128.wav
# FILE:  8039 - home depot samples 96k-6128.wav
# audio_files/8039 - home depot samples 96k-6128.wav
# New Filename: 1105.090275179203 8039 - home depot samples 96k-6128.wav
# Sum of all the elements of the array: 707.2577761146899
# The length of the array is: 64
# The average RMS of the sample is 1105.090275179203
# The max RMS value is: 10.220687836408615
#
# audio_files/8039 - home depot samples 96k-7236.wav
# FILE:  8039 - home depot samples 96k-7236.wav
# audio_files/8039 - home depot samples 96k-7236.wav
# New Filename: 1334.6426641517683 8039 - home depot samples 96k-7236.wav
# Sum of all the elements of the array: 707.3606120004372
# The length of the array is: 53
# The average RMS of the sample is 1334.6426641517683
# The max RMS value is: 11.934056878089905
#
# audio_files/8039 - home depot samples 96k-0559.wav
# FILE:  8039 - home depot samples 96k-0559.wav
# audio_files/8039 - home depot samples 96k-0559.wav
# New Filename: 1310.1330715948068 8039 - home depot samples 96k-0559.wav
# Sum of all the elements of the array: 707.4718586611957
# The length of the array is: 54
# The average RMS of the sample is 1310.1330715948068
# The max RMS value is: 11.282460764050484
#
# audio_files/8039 - home depot samples 96k-6896.wav
# FILE:  8039 - home depot samples 96k-6896.wav
# audio_files/8039 - home depot samples 96k-6896.wav
# New Filename: 1263.6352561815977 8039 - home depot samples 96k-6896.wav
# Sum of all the elements of the array: 707.6357434616947
# The length of the array is: 56
# The average RMS of the sample is 1263.6352561815977
# The max RMS value is: 13.2532250136137
#
# audio_files/8039 - home depot samples 96k-7550.wav
# FILE:  8039 - home depot samples 96k-7550.wav
# audio_files/8039 - home depot samples 96k-7550.wav
# New Filename: 1387.6570307529576 8039 - home depot samples 96k-7550.wav
# Sum of all the elements of the array: 707.7050856840084
# The length of the array is: 51
# The average RMS of the sample is 1387.6570307529576
# The max RMS value is: 9.511798620223999
#
# audio_files/8039 - home depot samples 96k-1121.wav
# FILE:  8039 - home depot samples 96k-1121.wav
# audio_files/8039 - home depot samples 96k-1121.wav
# New Filename: 1310.628471393162 8039 - home depot samples 96k-1121.wav
# Sum of all the elements of the array: 707.7393745523075
# The length of the array is: 54
# The average RMS of the sample is 1310.628471393162
# The max RMS value is: 3.822698723524809
#
# audio_files/8039 - home depot samples 96k-2428.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 17
#      15 if os.path.isfile(f):
#      16     file = f
# ---> 17     current_file, _ = librosa.load(file)
#      18     rms_current_file = librosa.feature.rms(y=current_file)[0]
#      19     # print("the directory is:  " + file)
#
# File ~/Desktop/audio_sort/envs/lib/python3.9/site-packages/librosa/core/audio.py:190, in load(path, sr, mono, offset, duration, dtype, res_type)
#     188 # Final cleanup for dtype and contiguity
#     189 if mono:
# --> 190     y = to_mono(y)
#     192 if sr is not None:
#     193     y = resample(y, orig_sr=sr_native, target_sr=sr, res_type=res_type)
#
# File ~/Desktop/audio_sort/envs/lib/python3.9/site-packages/librosa/core/audio.py:513, in to_mono(y)
#     510 util.valid_audio(y, mono=False)
#     512 if y.ndim > 1:
# --> 513     y = np.mean(y, axis=tuple(range(y.ndim - 1)))
#     515 return y
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File ~/Desktop/audio_sort/envs/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3464, in mean(a, axis, dtype, out, keepdims, where)
#    3461     else:
#    3462         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3464 return _methods._mean(a, axis=axis, dtype=dtype,
#    3465                       out=out, **kwargs)
#
# File ~/Desktop/audio_sort/envs/lib/python3.9/site-packages/numpy/core/_methods.py:181, in _mean(a, axis, dtype, out, keepdims, where)
#     178         dtype = mu.dtype('f4')
#     179         is_float16_result = True
# --> 181 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     182 if isinstance(ret, mu.ndarray):
#     183     with _no_nep50_warning():
#
# KeyboardInterrupt:

# %%
   # renames file in new directory
