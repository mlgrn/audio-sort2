# %%
import numpy as np
import librosa
import librosa.display
import os
import shutil

# %%
# load audio folder. Put whatever files you want to organize in here. 
directory = 'audio_files'
file = ''
sum=0
OUTPUT_BY_AVG = "output_by_avg"
OUTPUT_BY_LENGTH = "output_by_length"
OUTPUT_BY_SUM = "output_by_sum"


for filename in os.listdir(directory) :
    if not filename.startswith('.'):
        f = os.path.join(directory, filename)

        print(f)
        if os.path.isfile(f):
            file = f
            current_file, _ = librosa.load(file)
            rms_current_file = librosa.feature.rms(y=current_file)[0]
            # print("the directory is:  " + file)
            print("FILE:  " + filename)
            print(file)
            
            arr = rms_current_file
            array_length=len(arr)
            for i in range(0, len(arr)):
                sum=sum+arr[i]
            
            # sets variable with avg RMS value + filename
            new_name_avg =  str(sum/array_length*1000) + " " + str(filename)
            
            # sets variable sum value + filename
            new_name_sum =  str(sum) + " " + str(filename)

            # sets variable length value + filename
            new_name_length =  str(array_length) + " " + str(filename)
            

            print("New Filename: " + new_name_avg)
            print("Sum of all the elements of the array: " + str(sum));    
            print("The length of the array is: " + str(array_length));    
            print("The average RMS of the sample is " + str(sum/array_length*1000));
            print("")
        
            # copies the source files to output_by_avg
            shutil.copy(file, OUTPUT_BY_AVG)

            # renames the copied files with avg RMS as prefix
            old_name = OUTPUT_BY_AVG+"/"+filename
            rename = OUTPUT_BY_AVG+"/"+new_name_avg
            os.rename(old_name, rename)
        
        
        

            # copies the source files to output_by_sum
            shutil.copy(file, OUTPUT_BY_SUM)
            
            # # renames the copied files with sum as prefix
            old_name = OUTPUT_BY_SUM+"/"+filename
            rename = OUTPUT_BY_SUM+"/"+new_name_sum
            os.rename(old_name, rename)
            
        
             # copies the source files to output_by_length
            shutil.copy(file, OUTPUT_BY_LENGTH)

            # renames the copied files with sum as prefix
            old_name = OUTPUT_BY_LENGTH+"/"+filename
            rename = OUTPUT_BY_LENGTH+"/"+new_name_length
            os.rename(old_name, rename)
# Out:
# audio_files/8039 - home depot samples 96k-0003.wav
# FILE:  8039 - home depot samples 96k-0003.wav
# audio_files/8039 - home depot samples 96k-0003.wav
# New Filename: 4.927564919051418 8039 - home depot samples 96k-0003.wav
# Sum of all the elements of the array: 0.34492954433359924
# The length of the array is: 70
# The average RMS of the sample is 4.927564919051418
#
# audio_files/8039 - home depot samples 96k-0002.wav
# FILE:  8039 - home depot samples 96k-0002.wav
# audio_files/8039 - home depot samples 96k-0002.wav
# New Filename: 9.489819478549276 8039 - home depot samples 96k-0002.wav
# Sum of all the elements of the array: 0.5029604323631116
# The length of the array is: 53
# The average RMS of the sample is 9.489819478549276
#
# audio_files/8039 - home depot samples 96k-0014.wav
# FILE:  8039 - home depot samples 96k-0014.wav
# audio_files/8039 - home depot samples 96k-0014.wav
# New Filename: 12.568106008430345 8039 - home depot samples 96k-0014.wav
# Sum of all the elements of the array: 0.6661096184468083
# The length of the array is: 53
# The average RMS of the sample is 12.568106008430345
#
# audio_files/8039 - home depot samples 96k-0001.wav
# FILE:  8039 - home depot samples 96k-0001.wav
# audio_files/8039 - home depot samples 96k-0001.wav
# New Filename: 11.28331160625749 8039 - home depot samples 96k-0001.wav
# Sum of all the elements of the array: 0.8236817472567968
# The length of the array is: 73
# The average RMS of the sample is 11.28331160625749
#
# audio_files/8039 - home depot samples 96k-0015.wav
# FILE:  8039 - home depot samples 96k-0015.wav
# audio_files/8039 - home depot samples 96k-0015.wav
# New Filename: 7.087353267217248 8039 - home depot samples 96k-0015.wav
# Sum of all the elements of the array: 1.1623259358236286
# The length of the array is: 164
# The average RMS of the sample is 7.087353267217248
#
# audio_files/8039 - home depot samples 96k-0011.wav
# FILE:  8039 - home depot samples 96k-0011.wav
# audio_files/8039 - home depot samples 96k-0011.wav
# New Filename: 25.310019198019038 8039 - home depot samples 96k-0011.wav
# Sum of all the elements of the array: 1.265500959900952
# The length of the array is: 50
# The average RMS of the sample is 25.310019198019038
#
# audio_files/8039 - home depot samples 96k-0005.wav
# FILE:  8039 - home depot samples 96k-0005.wav
# audio_files/8039 - home depot samples 96k-0005.wav
# New Filename: 24.33113148023627 8039 - home depot samples 96k-0005.wav
# Sum of all the elements of the array: 1.6058546776955938
# The length of the array is: 66
# The average RMS of the sample is 24.33113148023627
#
# audio_files/8039 - home depot samples 96k-0004.wav
# FILE:  8039 - home depot samples 96k-0004.wav
# audio_files/8039 - home depot samples 96k-0004.wav
# New Filename: 35.528335678069965 8039 - home depot samples 96k-0004.wav
# Sum of all the elements of the array: 2.096171805006128
# The length of the array is: 59
# The average RMS of the sample is 35.528335678069965
#
# audio_files/8039 - home depot samples 96k-0010.wav
# FILE:  8039 - home depot samples 96k-0010.wav
# audio_files/8039 - home depot samples 96k-0010.wav
# New Filename: 37.71813706657281 8039 - home depot samples 96k-0010.wav
# Sum of all the elements of the array: 2.187651949861223
# The length of the array is: 58
# The average RMS of the sample is 37.71813706657281
#
# audio_files/8039 - home depot samples 96k-0006.wav
# FILE:  8039 - home depot samples 96k-0006.wav
# audio_files/8039 - home depot samples 96k-0006.wav
# New Filename: 28.937127394411316 8039 - home depot samples 96k-0006.wav
# Sum of all the elements of the array: 2.3149701915529053
# The length of the array is: 80
# The average RMS of the sample is 28.937127394411316
#
# audio_files/8039 - home depot samples 96k-0012.wav
# FILE:  8039 - home depot samples 96k-0012.wav
# audio_files/8039 - home depot samples 96k-0012.wav
# New Filename: 48.04356144009555 8039 - home depot samples 96k-0012.wav
# Sum of all the elements of the array: 2.546308756325064
# The length of the array is: 53
# The average RMS of the sample is 48.04356144009555
#
# audio_files/8039 - home depot samples 96k-0013.wav
# FILE:  8039 - home depot samples 96k-0013.wav
# audio_files/8039 - home depot samples 96k-0013.wav
# New Filename: 53.43070623340759 8039 - home depot samples 96k-0013.wav
# Sum of all the elements of the array: 2.8318274303706024
# The length of the array is: 53
# The average RMS of the sample is 53.43070623340759
#
# audio_files/8039 - home depot samples 96k-0007.wav
# FILE:  8039 - home depot samples 96k-0007.wav
# audio_files/8039 - home depot samples 96k-0007.wav
# New Filename: 52.44406376673248 8039 - home depot samples 96k-0007.wav
# Sum of all the elements of the array: 2.9368675709370184
# The length of the array is: 56
# The average RMS of the sample is 52.44406376673248
#
# audio_files/8039 - home depot samples 96k-0009.wav
# FILE:  8039 - home depot samples 96k-0009.wav
# audio_files/8039 - home depot samples 96k-0009.wav
# New Filename: 59.43591139834767 8039 - home depot samples 96k-0009.wav
# Sum of all the elements of the array: 2.9717955699173833
# The length of the array is: 50
# The average RMS of the sample is 59.43591139834767
#
# audio_files/8039 - home depot samples 96k-0008.wav
# FILE:  8039 - home depot samples 96k-0008.wav
# audio_files/8039 - home depot samples 96k-0008.wav
# New Filename: 46.19761926012493 8039 - home depot samples 96k-0008.wav
# Sum of all the elements of the array: 3.233833348208745
# The length of the array is: 70
# The average RMS of the sample is 46.19761926012493

# %%
   # renames file in new directory
